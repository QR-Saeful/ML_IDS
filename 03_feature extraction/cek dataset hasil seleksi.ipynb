# %%
dataset_base_path = r'/Users/kripik123/Documents/dataset/processedx/selected_features/'

#Removing invalid rows
import numpy as np
import pandas as pd
import os

file_path = os.path.join(dataset_base_path, 'selected_features.csv')

df = pd.read_csv(file_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16232943 entries, 0 to 16232942
# Data columns (total 32 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Unnamed: 0         int64
#  1   protocol           int64
#  2   flow_duration      float64
#  3   tot_fwd_pkts       int64
#  4   tot_bwd_pkts       int64
#  5   totlen_fwd_pkts    int64
#  6   totlen_bwd_pkts    int64
#  7   fwd_pkt_len_mean   float64
#  8   fwd_pkt_len_std    float64
#  9   bwd_pkt_len_mean   float64
#  10  flow_byts_s        float64
#  11  flow_pkts_s        float64
#  12  flow_iat_std       float64
#  13  flow_iat_min       float64
#  14  fwd_iat_tot        float64
#  15  fwd_iat_min        float64
#  16  bwd_iat_tot        int64
#  17  bwd_iat_min        int64
#  18  fwd_psh_flags      int64
#  19  fwd_urg_flags      int64
#  20  bwd_pkts_s         float64
#  21  fin_flag_cnt       int64
#  22  rst_flag_cnt       int64
#  23  psh_flag_cnt       int64
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  protocol  flow_duration  tot_fwd_pkts  tot_bwd_pkts  \
# 0           0         0    112640768.0             3             0
# 1           1         0    112641773.0             3             0
# 2           2         6     20784143.0            23            44
# 3           3         0    112640836.0             3             0
# 4           4         6           20.0             1             1
#
#    totlen_fwd_pkts  totlen_bwd_pkts  fwd_pkt_len_mean  fwd_pkt_len_std  \
# 0                0                0           0.00000         0.000000
# 1                0                0           0.00000         0.000000
# 2             2416             1344         105.04348        54.542294
# 3                0                0           0.00000         0.000000
# 4                0                0           0.00000         0.000000
#
#    bwd_pkt_len_mean  ...  rst_flag_cnt  psh_flag_cnt  ack_flag_cnt  \
# ...

# %%
df.tail()
# Out:
#           Unnamed: 0  protocol  flow_duration  tot_fwd_pkts  tot_bwd_pkts  \
# 16232938     1048570        17        61898.0             2             2
# 16232939     1048571         6     86213373.0             2             0
# 16232940     1048572        17          642.0             1             1
# 16232941     1048573        17        78472.0             1             1
# 16232942     1048574         6      2013403.0             8             7
#
#           totlen_fwd_pkts  totlen_bwd_pkts  fwd_pkt_len_mean  fwd_pkt_len_std  \
# 16232938               78              254              39.0          0.00000
# 16232939                0                0               0.0          0.00000
# 16232940               39               67              39.0          0.00000
# 16232941               32              121              32.0          0.00000
# 16232942             1144             1581             143.0        227.96992
#
# ...
