# %%
dataset_base_path = r'/Users/kripik123/Documents/dataset/processedx/'

import numpy as np
import pandas as pd
import os
import re

csv_files = {
 'infiltration_28-02-2018.csv':'infiltration_28-02-2018_x.csv',
 'infiltration_01-03-2018.csv': 'infiltration_01-03-2018_x.csv',
 'bot_02-03-2018.csv': 'bot_02-03-2018_x.csv',
 'bruteforce-web-xss_sql-injection_22-02-2018.csv': 'bruteforce-web-xss_sql-injection_22-02-2018_x.csv',
 'dos-goldeneye-slowloris_15-02-2018.csv': 'dos-goldeneye-slowloris_15-02-2018_x.csv',
 'ddos-loic-http-loic-udp_20-02-2018.csv': 'ddos-loic-http-loic-udp_20-02-2018_x.csv',
 'ddos-loic-udp_hoic_21-02-2018.csv': 'ddos-loic-udp_hoic_21-02-2018_x.csv',
 'bruteforce-ftp-ssh_14-02-2018.csv': 'bruteforce-ftp-ssh_14-02-2018_x.csv',
 'dos-slowhttp-hulk_16-02-2018.csv': 'dos-slowhttp-hulk_16-02-2018_x.csv',
 'bruteforce-web-xss_sql-injection_23-02-2018.csv': 'bruteforce-web-xss_sql-injection_23-02-2018_x.csv'
}

column_name_regex = re.compile(r"\W", re.IGNORECASE)
processed_dir = 'selected_fiture_per-dataset'
processed_path = os.path.join(dataset_base_path, processed_dir)


if not os.path.exists(processed_path):
    os.mkdir(processed_path)    
    
for f, out in csv_files.items():
    file_path = os.path.join(dataset_base_path, f)
    output_path = os.path.join(dataset_base_path, processed_dir, out)
    
    df = pd.read_csv(file_path)
    dfx = df.drop(columns=['dst_port', 'timestamp', 'totlen_fwd_pkts','fwd_pkt_len_max','fwd_pkt_len_min','bwd_pkt_len_max','bwd_pkt_len_min','bwd_pkt_len_std','flow_iat_mean','flow_iat_max','fwd_iat_mean','fwd_iat_std','fwd_iat_max',' bwd_iat_mean',
                          'bwd_iat_std','bwd_iat_max','bwd_psh_flags','bwd_urg_flags','fwd_header_len','bwd_header_len','fwd_pkts_s','pkt_len_min','pkt_len_max','pkt_len_mean','pkt_len_std','pkt_len_var','syn_flag_cnt','cwe_flag_count','ece_flag_cnt',
                          'pkt_size_avg','fwd_seg_size_avg','bwd_seg_size_avg','fwd_byts_b_avg','fwd_pkts_b_avg','fwd_blk_rate_avg','bwd_byts_b_avg','bwd_pkts_b_avg','bwd_blk_rate_avg','subflow_fwd_pkts','subflow_fwd_byts','subflow_bwd_pkts','subflow_bwd_byts',
                          'fwd_act_data_pkts','active_std','active_max','active_min','idle_std','idle_max','idle_min'], errors='ignore') ## fitur2 yang mau di drop, di masukan ke sini
    dfx.to_csv(output_path, index=False)

# %%
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 32 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   protocol           1048575 non-null  int64
#  1   flow_duration      1048575 non-null  int64
#  2   tot_fwd_pkts       1048575 non-null  int64
#  3   tot_bwd_pkts       1048575 non-null  int64
#  4   totlen_bwd_pkts    1048575 non-null  int64
#  5   fwd_pkt_len_mean   1048575 non-null  float64
#  6   fwd_pkt_len_std    1048575 non-null  float64
#  7   bwd_pkt_len_mean   1048575 non-null  float64
#  8   flow_byts_s        1044821 non-null  float64
#  9   flow_pkts_s        1048575 non-null  float64
#  10  flow_iat_std       1048575 non-null  float64
#  11  flow_iat_min       1048575 non-null  int64
#  12  fwd_iat_tot        1048575 non-null  int64
#  13  fwd_iat_min        1048575 non-null  int64
#  14  bwd_iat_tot        1048575 non-null  int64
# ...

# %%
dfx.head()
# Out:
#    protocol  flow_duration  tot_fwd_pkts  tot_bwd_pkts  totlen_bwd_pkts  \
# 0         6        1532698            11            11             1969
# 1        17      117573855             3             0                0
# 2        17      117573848             3             0                0
# 3         6        1745392            11            11             1969
# 4        17       89483474             6             0                0
#
#    fwd_pkt_len_mean  fwd_pkt_len_std  bwd_pkt_len_mean  flow_byts_s  \
# 0        107.181818       196.245162             179.0  2053.894505
# 1        500.000000         0.000000               0.0    12.757938
# 2        500.000000         0.000000               0.0    12.757939
# 3        107.181818       196.245162             179.0  1803.606296
# 4        500.000000         0.000000               0.0    33.525744
#
#    flow_pkts_s  ...  psh_flag_cnt  ack_flag_cnt  urg_flag_cnt  down_up_ratio  \
# ...

# %%
dfx.tail()
# Out:
#          protocol  flow_duration  tot_fwd_pkts  tot_bwd_pkts  totlen_bwd_pkts  \
# 1048570         6       85992425             2             0                0
# 1048571         6            132             2             0                0
# 1048572        17          79134             1             1               98
# 1048573         6       10053785            11            12             1659
# 1048574         6         566835             6             5              338
#
#          fwd_pkt_len_mean  fwd_pkt_len_std  bwd_pkt_len_mean  flow_byts_s  \
# 1048570          0.000000         0.000000              0.00     0.000000
# 1048571          0.000000         0.000000              0.00     0.000000
# 1048572         41.000000         0.000000             98.00  1756.514267
# 1048573        120.090909       197.116440            138.25   296.405782
# 1048574         75.833333        62.936211             67.60  1398.996181
#
# ...
